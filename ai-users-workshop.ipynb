# %% [markdown]
# <a href="https://www.kaggle.com/code/lukalafaye/ai-users-workshop?scriptVersionId=201553544" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
requirements = """
accelerate==0.32.1
aiohttp==3.9.5
aiosignal==1.3.1
altair==5.3.0
annotated-types==0.7.0
anthropic==0.30.1
anyio==4.4.0
appnope==0.1.4
asgiref==3.8.1
asttokens==2.4.1
async-timeout==4.0.3
attrs==23.2.0
backoff==2.2.1
bcrypt==4.1.3
beautifulsoup4==4.12.3
bitsandbytes==0.42.0
blinker==1.8.2
bs4==0.0.2
build==1.2.1
cachetools==5.3.3
certifi==2024.7.4
charset-normalizer==3.3.2
chroma-hnswlib==0.7.3
chromadb==0.5.3
click==8.1.7
coloredlogs==15.0.1
comm==0.2.2
dataclasses-json==0.6.7
datasets==2.20.0
debugpy==1.8.2
decorator==5.1.1
defusedxml==0.7.1
Deprecated==1.2.14
diffusers==0.29.2
dill==0.3.8
distro==1.9.0
dnspython==2.6.1
email_validator==2.2.0
exceptiongroup==1.2.1
executing==2.0.1
faiss-cpu==1.8.0.post1
fastapi==0.111.0
fastapi-cli==0.0.4
filelock==3.15.4
flatbuffers==24.3.25
frozenlist==1.4.1
fsspec==2024.5.0
gitdb==4.0.11
GitPython==3.1.43
google-auth==2.32.0
google_search_results==2.4.2
googleapis-common-protos==1.63.2
grpcio==1.64.1
h11==0.14.0
httpcore==1.0.5
httptools==0.6.1
httpx==0.27.0
huggingface-hub==0.23.4
humanfriendly==10.0
idna==3.7
importlib_metadata==7.1.0
importlib_resources==6.4.0
ipykernel==6.29.5
ipython==8.18.1
ipywidgets==8.1.3
jedi==0.19.1
Jinja2==3.1.4
jiter==0.5.0
joblib==1.4.2
jsonpatch==1.33
jsonpointer==3.0.0
jsonschema==4.22.0
jsonschema-specifications==2023.12.1
jupyter_client==8.6.2
jupyter_core==5.7.2
jupyterlab_widgets==3.0.11
kubernetes==30.1.0
langchain==0.2.7
langchain-anthropic==0.1.20
langchain-chroma==0.1.2
langchain-community==0.2.7
langchain-core==0.2.17
langchain-experimental==0.0.62
langchain-huggingface==0.0.3
langchain-openai==0.1.16
langchain-text-splitters==0.2.2
langchainhub==0.1.20
langgraph==0.1.8
langserve==0.2.2
langsmith==0.1.85
markdown-it-py==3.0.0
MarkupSafe==2.1.5
marshmallow==3.21.3
matplotlib-inline==0.1.7
mdurl==0.1.2
mmh3==4.1.0
monotonic==1.6
mpmath==1.3.0
multidict==6.0.5
multiprocess==0.70.16
mypy-extensions==1.0.0
nest-asyncio==1.6.0
networkx==3.2.1
numpy==1.26.4
oauthlib==3.2.2
onnxruntime==1.18.1
openai==1.35.10
opentelemetry-api==1.25.0
opentelemetry-exporter-otlp-proto-common==1.25.0
opentelemetry-exporter-otlp-proto-grpc==1.25.0
opentelemetry-instrumentation==0.46b0
opentelemetry-instrumentation-asgi==0.46b0
opentelemetry-instrumentation-fastapi==0.46b0
opentelemetry-proto==1.25.0
opentelemetry-sdk==1.25.0
opentelemetry-semantic-conventions==0.46b0
opentelemetry-util-http==0.46b0
orjson==3.10.6
overrides==7.7.0
packaging==24.1
pandas==2.2.2
parso==0.8.4
pexpect==4.9.0
pillow==10.4.0
platformdirs==4.2.2
posthog==3.5.0
prompt_toolkit==3.0.47
protobuf==4.25.3
psutil==6.0.0
ptyprocess==0.7.0
pure-eval==0.2.2
pyarrow==16.1.0
pyarrow-hotfix==0.6
pyasn1==0.6.0
pyasn1_modules==0.4.0
pydantic==2.8.2
pydantic_core==2.20.1
pydeck==0.9.1
Pygments==2.18.0
pypdf==4.2.0
PyPika==0.48.9
pyproject-toml==0.0.10
pyproject_hooks==1.1.0
python-dateutil==2.9.0.post0
python-dotenv==1.0.1
python-multipart==0.0.9
pytz==2024.1
PyYAML==6.0.1
pyzmq==26.0.3
referencing==0.35.1
regex==2024.5.15
requests==2.32.3
requests-oauthlib==2.0.0
rich==13.7.1
rpds-py==0.18.1
rsa==4.9
safetensors==0.4.3
scikit-learn==1.5.1
scipy==1.13.1
sentence-transformers==3.0.1
shellingham==1.5.4
six==1.16.0
smmap==5.0.1
sniffio==1.3.1
soupsieve==2.5
SQLAlchemy==2.0.31
sse-starlette==1.8.2
stack-data==0.6.3
starlette==0.37.2
streamlit==1.36.0
sympy==1.13.0
tavily-python==0.3.4
tenacity==8.5.0
threadpoolctl==3.5.0
tiktoken==0.7.0
tokenizers==0.19.1
toml==0.10.2
tomli==2.0.1
toolz==0.12.1
torch==2.3.1
torchaudio==2.3.1
torchvision==0.18.1
tornado==6.4.1
tqdm==4.66.4
traitlets==5.14.3
transformers==4.42.4
typer==0.12.3
types-requests==2.32.0.20240712
typing-inspect==0.9.0
typing_extensions==4.12.2
tzdata==2024.1
ujson==5.10.0
urllib3==2.2.2
uvicorn==0.30.1
uvloop==0.19.0
watchfiles==0.22.0
wcwidth==0.2.13
websocket-client==1.8.0
websockets==12.0
widgetsnbextension==4.0.11
wrapt==1.16.0
xxhash==3.4.1
yarl==1.9.4
zipp==3.19.2"""

# %%
with open("requirements.txt", "w") as f:
    f.write(requirements)

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: accelerate==0.32.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.32.1)
# Collecting aiohttp==3.9.5 (from -r requirements.txt (line 3))
#   Using cached aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: aiosignal==1.3.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: altair==5.3.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (5.3.0)
# Requirement already satisfied: annotated-types==0.7.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (0.7.0)
# Collecting anthropic==0.30.1 (from -r requirements.txt (line 7))
#   Using cached anthropic-0.30.1-py3-none-any.whl.metadata (18 kB)
# Collecting anyio==4.4.0 (from -r requirements.txt (line 8))
#   Using cached anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: appnope==0.1.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (0.1.4)
# Collecting asgiref==3.8.1 (from -r requirements.txt (line 10))
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: asttokens==2.4.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (2.4.1)
# Requirement already satisfied: async-timeout==4.0.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (4.0.3)
# Requirement already satisfied: attrs==23.2.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (23.2.0)
# Requirement already satisfied: backoff==2.2.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (2.2.1)
# Requirement already satisfied: bcrypt==4.1.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (4.1.3)
# Requirement already satisfied: beautifulsoup4==4.12.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (4.12.3)
# Collecting bitsandbytes==0.42.0 (from -r requirements.txt (line 17))
#   Using cached bitsandbytes-0.42.0-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: blinker==1.8.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (1.8.2)
# Collecting bs4==0.0.2 (from -r requirements.txt (line 19))
#   Using cached bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting build==1.2.1 (from -r requirements.txt (line 20))
#   Using cached build-1.2.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting cachetools==5.3.3 (from -r requirements.txt (line 21))
#   Using cached cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: certifi==2024.7.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (2024.7.4)
# Requirement already satisfied: charset-normalizer==3.3.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 23)) (3.3.2)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (0.7.3)
# Collecting chromadb==0.5.3 (from -r requirements.txt (line 25))
#   Using cached chromadb-0.5.3-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: click==8.1.7 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 26)) (8.1.7)
# Collecting coloredlogs==15.0.1 (from -r requirements.txt (line 27))
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting comm==0.2.2 (from -r requirements.txt (line 28))
#   Using cached comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: dataclasses-json==0.6.7 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 29)) (0.6.7)
# Requirement already satisfied: datasets==2.20.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 30)) (2.20.0)
# Collecting debugpy==1.8.2 (from -r requirements.txt (line 31))
#   Using cached debugpy-1.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: decorator==5.1.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 32)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 33)) (0.7.1)
# Requirement already satisfied: Deprecated==1.2.14 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 34)) (1.2.14)
# Collecting diffusers==0.29.2 (from -r requirements.txt (line 35))
#   Using cached diffusers-0.29.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: dill==0.3.8 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 36)) (0.3.8)
# Requirement already satisfied: distro==1.9.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 37)) (1.9.0)
# Requirement already satisfied: dnspython==2.6.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 38)) (2.6.1)
# Collecting email_validator==2.2.0 (from -r requirements.txt (line 39))
#   Using cached email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: exceptiongroup==1.2.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 40)) (1.2.1)
# Requirement already satisfied: executing==2.0.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 41)) (2.0.1)
# Collecting faiss-cpu==1.8.0.post1 (from -r requirements.txt (line 42))
#   Using cached faiss_cpu-1.8.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Collecting fastapi==0.111.0 (from -r requirements.txt (line 43))
#   Using cached fastapi-0.111.0-py3-none-any.whl.metadata (25 kB)
# Collecting fastapi-cli==0.0.4 (from -r requirements.txt (line 44))
#   Using cached fastapi_cli-0.0.4-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: filelock==3.15.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 45)) (3.15.4)
# Requirement already satisfied: flatbuffers==24.3.25 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 46)) (24.3.25)
# Requirement already satisfied: frozenlist==1.4.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 47)) (1.4.1)
# Requirement already satisfied: fsspec==2024.5.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 48)) (2024.5.0)
# Requirement already satisfied: gitdb==4.0.11 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 49)) (4.0.11)
# Collecting GitPython==3.1.43 (from -r requirements.txt (line 50))
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting google-auth==2.32.0 (from -r requirements.txt (line 51))
#   Using cached google_auth-2.32.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google_search_results==2.4.2 (from -r requirements.txt (line 52))
#   Using cached google_search_results-2.4.2-py3-none-any.whl
# Collecting googleapis-common-protos==1.63.2 (from -r requirements.txt (line 53))
#   Using cached googleapis_common_protos-1.63.2-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: grpcio==1.64.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 54)) (1.64.1)
# Requirement already satisfied: h11==0.14.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 55)) (0.14.0)
# Requirement already satisfied: httpcore==1.0.5 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 56)) (1.0.5)
# Requirement already satisfied: httptools==0.6.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 57)) (0.6.1)
# Requirement already satisfied: httpx==0.27.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 58)) (0.27.0)
# Requirement already satisfied: huggingface-hub==0.23.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 59)) (0.23.4)
# Requirement already satisfied: humanfriendly==10.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 60)) (10.0)
# Requirement already satisfied: idna==3.7 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 61)) (3.7)
# Collecting importlib_metadata==7.1.0 (from -r requirements.txt (line 62))
#   Using cached importlib_metadata-7.1.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: importlib_resources==6.4.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 63)) (6.4.0)
# Collecting ipykernel==6.29.5 (from -r requirements.txt (line 64))
#   Using cached ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting ipython==8.18.1 (from -r requirements.txt (line 65))
#   Using cached ipython-8.18.1-py3-none-any.whl.metadata (6.0 kB)
# Collecting ipywidgets==8.1.3 (from -r requirements.txt (line 66))
#   Using cached ipywidgets-8.1.3-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: jedi==0.19.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 67)) (0.19.1)
# Collecting Jinja2==3.1.4 (from -r requirements.txt (line 68))
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: jiter==0.5.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 69)) (0.5.0)
# Requirement already satisfied: joblib==1.4.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 70)) (1.4.2)
# Requirement already satisfied: jsonpatch==1.33 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 71)) (1.33)
# Requirement already satisfied: jsonpointer==3.0.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 72)) (3.0.0)
# Collecting jsonschema==4.22.0 (from -r requirements.txt (line 73))
#   Using cached jsonschema-4.22.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: jsonschema-specifications==2023.12.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 74)) (2023.12.1)
# Collecting jupyter_client==8.6.2 (from -r requirements.txt (line 75))
#   Using cached jupyter_client-8.6.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter_core==5.7.2 (from -r requirements.txt (line 76))
#   Using cached jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: jupyterlab_widgets==3.0.11 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 77)) (3.0.11)
# Collecting kubernetes==30.1.0 (from -r requirements.txt (line 78))
#   Using cached kubernetes-30.1.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain==0.2.7 (from -r requirements.txt (line 79))
#   Using cached langchain-0.2.7-py3-none-any.whl.metadata (6.9 kB)
# Collecting langchain-anthropic==0.1.20 (from -r requirements.txt (line 80))
#   Using cached langchain_anthropic-0.1.20-py3-none-any.whl.metadata (2.1 kB)
# Collecting langchain-chroma==0.1.2 (from -r requirements.txt (line 81))
#   Using cached langchain_chroma-0.1.2-py3-none-any.whl.metadata (1.3 kB)
# Collecting langchain-community==0.2.7 (from -r requirements.txt (line 82))
#   Using cached langchain_community-0.2.7-py3-none-any.whl.metadata (2.5 kB)
# Collecting langchain-core==0.2.17 (from -r requirements.txt (line 83))
#   Using cached langchain_core-0.2.17-py3-none-any.whl.metadata (6.0 kB)
# Collecting langchain-experimental==0.0.62 (from -r requirements.txt (line 84))
#   Using cached langchain_experimental-0.0.62-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-huggingface==0.0.3 (from -r requirements.txt (line 85))
#   Using cached langchain_huggingface-0.0.3-py3-none-any.whl.metadata (1.2 kB)
# Collecting langchain-openai==0.1.16 (from -r requirements.txt (line 86))
#   Using cached langchain_openai-0.1.16-py3-none-any.whl.metadata (2.5 kB)
# Collecting langchain-text-splitters==0.2.2 (from -r requirements.txt (line 87))
#   Using cached langchain_text_splitters-0.2.2-py3-none-any.whl.metadata (2.1 kB)
# Collecting langchainhub==0.1.20 (from -r requirements.txt (line 88))
#   Using cached langchainhub-0.1.20-py3-none-any.whl.metadata (659 bytes)
# Collecting langgraph==0.1.8 (from -r requirements.txt (line 89))
#   Using cached langgraph-0.1.8-py3-none-any.whl.metadata (13 kB)
# Collecting langserve==0.2.2 (from -r requirements.txt (line 90))
#   Using cached langserve-0.2.2-py3-none-any.whl.metadata (39 kB)
# Collecting langsmith==0.1.85 (from -r requirements.txt (line 91))
#   Using cached langsmith-0.1.85-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: markdown-it-py==3.0.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 92)) (3.0.0)
# Requirement already satisfied: MarkupSafe==2.1.5 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 93)) (2.1.5)
# Requirement already satisfied: marshmallow==3.21.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 94)) (3.21.3)
# Collecting matplotlib-inline==0.1.7 (from -r requirements.txt (line 95))
#   Using cached matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: mdurl==0.1.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 96)) (0.1.2)
# Requirement already satisfied: mmh3==4.1.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 97)) (4.1.0)
# Requirement already satisfied: monotonic==1.6 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 98)) (1.6)
# Requirement already satisfied: mpmath==1.3.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 99)) (1.3.0)
# Collecting multidict==6.0.5 (from -r requirements.txt (line 100))
#   Using cached multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: multiprocess==0.70.16 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 101)) (0.70.16)
# Requirement already satisfied: mypy-extensions==1.0.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 102)) (1.0.0)
# Collecting nest-asyncio==1.6.0 (from -r requirements.txt (line 103))
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: networkx==3.2.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 104)) (3.2.1)
# Requirement already satisfied: numpy==1.26.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 105)) (1.26.4)
# Requirement already satisfied: oauthlib==3.2.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 106)) (3.2.2)
# Collecting onnxruntime==1.18.1 (from -r requirements.txt (line 107))
#   Using cached onnxruntime-1.18.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Collecting openai==1.35.10 (from -r requirements.txt (line 108))
#   Using cached openai-1.35.10-py3-none-any.whl.metadata (21 kB)
# Collecting opentelemetry-api==1.25.0 (from -r requirements.txt (line 109))
#   Using cached opentelemetry_api-1.25.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.25.0 (from -r requirements.txt (line 110))
#   Using cached opentelemetry_exporter_otlp_proto_common-1.25.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.25.0 (from -r requirements.txt (line 111))
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation==0.46b0 (from -r requirements.txt (line 112))
#   Using cached opentelemetry_instrumentation-0.46b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-instrumentation-asgi==0.46b0 (from -r requirements.txt (line 113))
#   Using cached opentelemetry_instrumentation_asgi-0.46b0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-instrumentation-fastapi==0.46b0 (from -r requirements.txt (line 114))
#   Using cached opentelemetry_instrumentation_fastapi-0.46b0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 115)) (1.25.0)
# Collecting opentelemetry-sdk==1.25.0 (from -r requirements.txt (line 116))
#   Using cached opentelemetry_sdk-1.25.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-semantic-conventions==0.46b0 (from -r requirements.txt (line 117))
#   Using cached opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 118)) (0.46b0)
# Requirement already satisfied: orjson==3.10.6 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 119)) (3.10.6)
# Requirement already satisfied: overrides==7.7.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 120)) (7.7.0)
# Requirement already satisfied: packaging==24.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 121)) (24.1)
# Requirement already satisfied: pandas==2.2.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 122)) (2.2.2)
# Collecting parso==0.8.4 (from -r requirements.txt (line 123))
#   Using cached parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: pexpect==4.9.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 124)) (4.9.0)
# Requirement already satisfied: pillow==10.4.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 125)) (10.4.0)
# Collecting platformdirs==4.2.2 (from -r requirements.txt (line 126))
#   Using cached platformdirs-4.2.2-py3-none-any.whl.metadata (11 kB)
# Collecting posthog==3.5.0 (from -r requirements.txt (line 127))
#   Using cached posthog-3.5.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting prompt_toolkit==3.0.47 (from -r requirements.txt (line 128))
#   Using cached prompt_toolkit-3.0.47-py3-none-any.whl.metadata (6.4 kB)
# Collecting protobuf==4.25.3 (from -r requirements.txt (line 129))
#   Using cached protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting psutil==6.0.0 (from -r requirements.txt (line 130))
#   Using cached psutil-6.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: ptyprocess==0.7.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 131)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 132)) (0.2.2)
# Requirement already satisfied: pyarrow==16.1.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 133)) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix==0.6 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 134)) (0.6)
# Collecting pyasn1==0.6.0 (from -r requirements.txt (line 135))
#   Using cached pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting pyasn1_modules==0.4.0 (from -r requirements.txt (line 136))
#   Using cached pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting pydantic==2.8.2 (from -r requirements.txt (line 137))
#   Using cached pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# Requirement already satisfied: pydantic_core==2.20.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 138)) (2.20.1)
# Collecting pydeck==0.9.1 (from -r requirements.txt (line 139))
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: Pygments==2.18.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 140)) (2.18.0)
# Requirement already satisfied: pypdf==4.2.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 141)) (4.2.0)
# Requirement already satisfied: PyPika==0.48.9 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 142)) (0.48.9)
# Collecting pyproject-toml==0.0.10 (from -r requirements.txt (line 143))
#   Using cached pyproject_toml-0.0.10-py3-none-any.whl.metadata (642 bytes)
# Requirement already satisfied: pyproject_hooks==1.1.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 144)) (1.1.0)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 145)) (2.9.0.post0)
# Requirement already satisfied: python-dotenv==1.0.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 146)) (1.0.1)
# Requirement already satisfied: python-multipart==0.0.9 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 147)) (0.0.9)
# Requirement already satisfied: pytz==2024.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 148)) (2024.1)
# Requirement already satisfied: PyYAML==6.0.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 149)) (6.0.1)
# Collecting pyzmq==26.0.3 (from -r requirements.txt (line 150))
#   Using cached pyzmq-26.0.3-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: referencing==0.35.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 151)) (0.35.1)
# Requirement already satisfied: regex==2024.5.15 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 152)) (2024.5.15)
# Requirement already satisfied: requests==2.32.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 153)) (2.32.3)
# Collecting requests-oauthlib==2.0.0 (from -r requirements.txt (line 154))
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: rich==13.7.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 155)) (13.7.1)
# Requirement already satisfied: rpds-py==0.18.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 156)) (0.18.1)
# Requirement already satisfied: rsa==4.9 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 157)) (4.9)
# Requirement already satisfied: safetensors==0.4.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 158)) (0.4.3)
# Requirement already satisfied: scikit-learn==1.5.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 159)) (1.5.1)
# Requirement already satisfied: scipy==1.13.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 160)) (1.13.1)
# Collecting sentence-transformers==3.0.1 (from -r requirements.txt (line 161))
#   Using cached sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: shellingham==1.5.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 162)) (1.5.4)
# Requirement already satisfied: six==1.16.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 163)) (1.16.0)
# Requirement already satisfied: smmap==5.0.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 164)) (5.0.1)
# Requirement already satisfied: sniffio==1.3.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 165)) (1.3.1)
# Requirement already satisfied: soupsieve==2.5 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 166)) (2.5)
# Requirement already satisfied: SQLAlchemy==2.0.31 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 167)) (2.0.31)
# Collecting sse-starlette==1.8.2 (from -r requirements.txt (line 168))
#   Using cached sse_starlette-1.8.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: stack-data==0.6.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 169)) (0.6.3)
# Collecting starlette==0.37.2 (from -r requirements.txt (line 170))
#   Using cached starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting streamlit==1.36.0 (from -r requirements.txt (line 171))
#   Using cached streamlit-1.36.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: sympy==1.13.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 172)) (1.13.0)
# Collecting tavily-python==0.3.4 (from -r requirements.txt (line 173))
#   Using cached tavily_python-0.3.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: tenacity==8.5.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 174)) (8.5.0)
# Requirement already satisfied: threadpoolctl==3.5.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 175)) (3.5.0)
# Collecting tiktoken==0.7.0 (from -r requirements.txt (line 176))
#   Using cached tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tokenizers==0.19.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 177)) (0.19.1)
# Requirement already satisfied: toml==0.10.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 178)) (0.10.2)
# Requirement already satisfied: tomli==2.0.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 179)) (2.0.1)
# Requirement already satisfied: toolz==0.12.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 180)) (0.12.1)
# Collecting torch==2.3.1 (from -r requirements.txt (line 181))
#   Using cached torch-2.3.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchaudio==2.3.1 (from -r requirements.txt (line 182))
#   Using cached torchaudio-2.3.1-cp310-cp310-manylinux1_x86_64.whl.metadata (6.4 kB)
# Collecting torchvision==0.18.1 (from -r requirements.txt (line 183))
#   Using cached torchvision-0.18.1-cp310-cp310-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tornado==6.4.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 184)) (6.4.1)
# Requirement already satisfied: tqdm==4.66.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 185)) (4.66.4)
# Requirement already satisfied: traitlets==5.14.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 186)) (5.14.3)
# Collecting transformers==4.42.4 (from -r requirements.txt (line 187))
#   Using cached transformers-4.42.4-py3-none-any.whl.metadata (43 kB)
# Collecting typer==0.12.3 (from -r requirements.txt (line 188))
#   Using cached typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: types-requests==2.32.0.20240712 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 189)) (2.32.0.20240712)
# Requirement already satisfied: typing-inspect==0.9.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 190)) (0.9.0)
# Requirement already satisfied: typing_extensions==4.12.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 191)) (4.12.2)
# Requirement already satisfied: tzdata==2024.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 192)) (2024.1)
# Requirement already satisfied: ujson==5.10.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 193)) (5.10.0)
# Collecting urllib3==2.2.2 (from -r requirements.txt (line 194))
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: uvicorn==0.30.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 195)) (0.30.1)
# Requirement already satisfied: uvloop==0.19.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 196)) (0.19.0)
# Collecting watchfiles==0.22.0 (from -r requirements.txt (line 197))
#   Using cached watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: wcwidth==0.2.13 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 198)) (0.2.13)
# Requirement already satisfied: websocket-client==1.8.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 199)) (1.8.0)
# Requirement already satisfied: websockets==12.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 200)) (12.0)
# Requirement already satisfied: widgetsnbextension==4.0.11 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 201)) (4.0.11)
# Requirement already satisfied: wrapt==1.16.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 202)) (1.16.0)
# Requirement already satisfied: xxhash==3.4.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 203)) (3.4.1)
# Requirement already satisfied: yarl==1.9.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 204)) (1.9.4)
# Requirement already satisfied: zipp==3.19.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 205)) (3.19.2)
# Requirement already satisfied: setuptools>=16.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.46b0->-r requirements.txt (line 112)) (69.0.3)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from pyproject-toml==0.0.10->-r requirements.txt (line 143)) (0.42.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy==2.0.31->-r requirements.txt (line 167)) (3.0.3)
# Requirement already satisfied: watchdog<5,>=2.1.5 in /opt/conda/lib/python3.10/site-packages (from streamlit==1.36.0->-r requirements.txt (line 171)) (4.0.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->-r requirements.txt (line 181)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->-r requirements.txt (line 181)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->-r requirements.txt (line 181)) (12.1.105)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.3.1->-r requirements.txt (line 181))
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->-r requirements.txt (line 181)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->-r requirements.txt (line 181)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->-r requirements.txt (line 181)) (10.3.2.106)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.3.1->-r requirements.txt (line 181))
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->-r requirements.txt (line 181)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->-r requirements.txt (line 181)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->-r requirements.txt (line 181)) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->-r requirements.txt (line 181)) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.1->-r requirements.txt (line 181)) (12.5.82)
# Using cached aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Using cached anthropic-0.30.1-py3-none-any.whl (863 kB)
# Using cached anyio-4.4.0-py3-none-any.whl (86 kB)
# Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Using cached bitsandbytes-0.42.0-py3-none-any.whl (105.0 MB)
# Using cached bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Using cached build-1.2.1-py3-none-any.whl (21 kB)
# Using cached cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Using cached chromadb-0.5.3-py3-none-any.whl (559 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached comm-0.2.2-py3-none-any.whl (7.2 kB)
# Using cached debugpy-1.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# Using cached diffusers-0.29.2-py3-none-any.whl (2.2 MB)
# Using cached email_validator-2.2.0-py3-none-any.whl (33 kB)
# Using cached faiss_cpu-1.8.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.0 MB)
# Using cached fastapi-0.111.0-py3-none-any.whl (91 kB)
# Using cached fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Using cached google_auth-2.32.0-py2.py3-none-any.whl (195 kB)
# Using cached googleapis_common_protos-1.63.2-py2.py3-none-any.whl (220 kB)
# Using cached importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Using cached ipykernel-6.29.5-py3-none-any.whl (117 kB)
# Using cached ipython-8.18.1-py3-none-any.whl (808 kB)
# Using cached ipywidgets-8.1.3-py3-none-any.whl (139 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached jsonschema-4.22.0-py3-none-any.whl (88 kB)
# Using cached jupyter_client-8.6.2-py3-none-any.whl (105 kB)
# Using cached jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Using cached kubernetes-30.1.0-py2.py3-none-any.whl (1.7 MB)
# Using cached langchain-0.2.7-py3-none-any.whl (983 kB)
# Using cached langchain_anthropic-0.1.20-py3-none-any.whl (20 kB)
# Using cached langchain_chroma-0.1.2-py3-none-any.whl (9.3 kB)
# Using cached langchain_community-0.2.7-py3-none-any.whl (2.2 MB)
# Using cached langchain_core-0.2.17-py3-none-any.whl (366 kB)
# Using cached langchain_experimental-0.0.62-py3-none-any.whl (202 kB)
# Using cached langchain_huggingface-0.0.3-py3-none-any.whl (17 kB)
# Using cached langchain_openai-0.1.16-py3-none-any.whl (46 kB)
# Using cached langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Using cached langchainhub-0.1.20-py3-none-any.whl (5.0 kB)
# Using cached langgraph-0.1.8-py3-none-any.whl (91 kB)
# Using cached langserve-0.2.2-py3-none-any.whl (1.2 MB)
# Using cached langsmith-0.1.85-py3-none-any.whl (127 kB)
# Using cached matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Using cached multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
# Using cached nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Using cached onnxruntime-1.18.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
# Using cached openai-1.35.10-py3-none-any.whl (328 kB)
# Using cached opentelemetry_api-1.25.0-py3-none-any.whl (59 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.25.0-py3-none-any.whl (17 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.25.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_instrumentation-0.46b0-py3-none-any.whl (29 kB)
# Using cached opentelemetry_instrumentation_asgi-0.46b0-py3-none-any.whl (14 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.46b0-py3-none-any.whl (11 kB)
# Using cached opentelemetry_sdk-1.25.0-py3-none-any.whl (107 kB)
# Using cached opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl (130 kB)
# Using cached parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Using cached platformdirs-4.2.2-py3-none-any.whl (18 kB)
# Using cached posthog-3.5.0-py2.py3-none-any.whl (41 kB)
# Using cached prompt_toolkit-3.0.47-py3-none-any.whl (386 kB)
# Using cached protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Using cached psutil-6.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (290 kB)
# Using cached pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
# Using cached pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
# Using cached pydantic-2.8.2-py3-none-any.whl (423 kB)
# Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Using cached pyproject_toml-0.0.10-py3-none-any.whl (6.9 kB)
# Using cached pyzmq-26.0.3-cp310-cp310-manylinux_2_28_x86_64.whl (919 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
# Using cached sse_starlette-1.8.2-py3-none-any.whl (8.9 kB)
# Using cached starlette-0.37.2-py3-none-any.whl (71 kB)
# Using cached streamlit-1.36.0-py2.py3-none-any.whl (8.6 MB)
# Using cached tavily_python-0.3.4-py3-none-any.whl (10 kB)
# Using cached tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Using cached torch-2.3.1-cp310-cp310-manylinux1_x86_64.whl (779.1 MB)
# Using cached torchaudio-2.3.1-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
# Using cached torchvision-0.18.1-cp310-cp310-manylinux1_x86_64.whl (7.0 MB)
# Using cached transformers-4.42.4-py3-none-any.whl (9.3 MB)
# Using cached typer-0.12.3-py3-none-any.whl (47 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Using cached watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# WARNING: Error parsing requirements for debugpy: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/debugpy-1.8.0.dist-info/METADATA'
# WARNING: Error parsing requirements for multidict: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/multidict-6.0.4.dist-info/METADATA'
# WARNING: Error parsing requirements for nest-asyncio: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/nest_asyncio-1.5.8.dist-info/METADATA'
# WARNING: Error parsing requirements for parso: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/parso-0.8.3.dist-info/METADATA'
# WARNING: Error parsing requirements for pyasn1: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/pyasn1-0.5.1.dist-info/METADATA'
# WARNING: Error parsing requirements for pyasn1-modules: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/pyasn1_modules-0.3.0.dist-info/METADATA'
# Installing collected packages: urllib3, pyzmq, pyasn1, psutil, protobuf, prompt_toolkit, platformdirs, parso, nvidia-cudnn-cu12, nest-asyncio, multidict, matplotlib-inline, Jinja2, importlib_metadata, faiss-cpu, email_validator, debugpy, comm, coloredlogs, cachetools, build, asgiref, anyio, watchfiles, starlette, pydeck, pydantic, pyasn1_modules, opentelemetry-api, onnxruntime, nvidia-cusolver-cu12, jupyter_core, googleapis-common-protos, GitPython, bs4, bitsandbytes, typer, torch, tiktoken, requests-oauthlib, posthog, opentelemetry-semantic-conventions, opentelemetry-instrumentation, opentelemetry-exporter-otlp-proto-common, openai, langsmith, langchainhub, jupyter_client, jsonschema, ipython, google_search_results, google-auth, aiohttp, torchvision, torchaudio, tavily-python, pyproject-toml, opentelemetry-sdk, opentelemetry-instrumentation-asgi, langchain-core, kubernetes, ipywidgets, ipykernel, fastapi-cli, diffusers, transformers, streamlit, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, langserve, langgraph, langchain-text-splitters, langchain-openai, fastapi, anthropic, sse-starlette, sentence-transformers, langchain-anthropic, langchain, chromadb, langchain-huggingface, langchain-community, langchain-chroma, langchain-experimental
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.1.0
#     Uninstalling urllib3-2.1.0:
#       Successfully uninstalled urllib3-2.1.0
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 25.1.2
#     Uninstalling pyzmq-25.1.2:
#       Successfully uninstalled pyzmq-25.1.2
#   Attempting uninstall: pyasn1
#     WARNING: No metadata found in /opt/conda/lib/python3.10/site-packages
#     Found existing installation: pyasn1 0.5.1
# ERROR: Cannot uninstall pyasn1 0.5.1, RECORD file not found. You might be able to recover from this via: 'pip install --force-reinstall --no-deps pyasn1==0.5.1'.

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /opt/conda/lib/python3.10/site-packages (1.37.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.10/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from openai) (2.5.3)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/conda/lib/python3.10/site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /opt/conda/lib/python3.10/site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.14.6)
# WARNING: Error parsing requirements for debugpy: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/debugpy-1.8.0.dist-info/METADATA'
# WARNING: Error parsing requirements for multidict: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/multidict-6.0.4.dist-info/METADATA'
# WARNING: Error parsing requirements for nest-asyncio: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/nest_asyncio-1.5.8.dist-info/METADATA'
# WARNING: Error parsing requirements for parso: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/parso-0.8.3.dist-info/METADATA'
# WARNING: Error parsing requirements for pyasn1: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/pyasn1-0.5.1.dist-info/METADATA'
# WARNING: Error parsing requirements for pyasn1-modules: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/pyasn1_modules-0.3.0.dist-info/METADATA'

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
api_key = user_secrets.get_secret("OPENAI_API_KEY")

# %%
from openai import OpenAI
client = OpenAI(api_key=api_key)

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Say this is a test",
        }
    ],
    model="gpt-3.5-turbo",
)

# %%
chat_completion
# Out:
# ChatCompletion(id='chatcmpl-9rCm3QDueE8cnzLy3HjuAROzJI2rB', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='This is a test', role='assistant', function_call=None, tool_calls=None))], created=1722467515, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=4, prompt_tokens=12, total_tokens=16))

# %%
completion = client.chat.completions.create(
  model="gpt-3.5-turbo-0125",
  messages=[
    {"role": "system", "content": "You are an expert fitness trainer that specializes in helping people prep for the first competitive event."},
    {"role": "user", "content": "Provide me with a training plan to prepare for my 5k in 4 weeks. I want to run it in under 28 minutes."}
  ],
  temperature=1,
  max_tokens=1024,
  seed=42,
  
)
print(completion.choices[0].message.content)
# Out:
# Sure, I can definitely help you with that! Here's a 4-week training plan to prepare you for your 5k and achieve your goal of running it in under 28 minutes:
#
# ### Week 1:
# - **Day 1**: 2-mile easy run
# - **Day 2**: Rest or cross-training (low impact)
# - **Day 3**: Interval training - 4 x 400m at a fast pace with 200m recovery jog in between
# - **Day 4**: Rest or cross-training (low impact)
# - **Day 5**: 2-mile easy run
# - **Day 6**: Rest
# - **Day 7**: Long run - 3 miles at a comfortable pace
#
# ### Week 2:
# - **Day 1**: 2-mile easy run
# - **Day 2**: Rest or cross-training (low impact)
# - **Day 3**: Fartlek training - 30 minutes of alternating between a fast pace and a recovery pace
# - **Day 4**: Rest or cross-training (low impact)
# - **Day 5**: 2-mile easy run
# - **Day 6**: Rest
# - **Day 7**: Long run - 4 miles at a comfortable pace
#
# ### Week 3:
# - **Day 1**: 2-mile easy run
# - **Day 2**: Rest or cross-training (low impact)
# - **Day 3**: Hill repeats - 6 x 200m uphill sprints with jog down recovery
# - **Day 4**: Rest or cross-training (low impact)
# - **Day 5**: 2-mile easy run
# - **Day 6**: Rest
# - **Day 7**: Long run - 5 miles at a comfortable pace
#
# ### Week 4:
# - **Day 1**: 2-mile easy run
# - **Day 2**: Rest or cross-training (low impact)
# - **Day 3**: Tempo run - 2 miles at a challenging pace
# - **Day 4**: Rest or cross-training (low impact)
# - **Day 5**: 1-mile easy run
# - **Day 6**: Rest
# - **Day 7**: Race day!
#
# Remember to gradually increase your pace and distance throughout the weeks, listen to your body, stay hydrated, eat well, and get plenty of rest to allow for recovery. Good luck with your 5k race! Let me know if you have any questions or need further advice.

# %%
from pprint import pprint 
pprint(vars(completion))
# Out:
# {'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Sure, I can definitely help you with that! Here's a 4-week training plan to prepare you for your 5k and achieve your goal of running it in under 28 minutes:\n\n### Week 1:\n- **Day 1**: 2-mile easy run\n- **Day 2**: Rest or cross-training (low impact)\n- **Day 3**: Interval training - 4 x 400m at a fast pace with 200m recovery jog in between\n- **Day 4**: Rest or cross-training (low impact)\n- **Day 5**: 2-mile easy run\n- **Day 6**: Rest\n- **Day 7**: Long run - 3 miles at a comfortable pace\n\n### Week 2:\n- **Day 1**: 2-mile easy run\n- **Day 2**: Rest or cross-training (low impact)\n- **Day 3**: Fartlek training - 30 minutes of alternating between a fast pace and a recovery pace\n- **Day 4**: Rest or cross-training (low impact)\n- **Day 5**: 2-mile easy run\n- **Day 6**: Rest\n- **Day 7**: Long run - 4 miles at a comfortable pace\n\n### Week 3:\n- **Day 1**: 2-mile easy run\n- **Day 2**: Rest or cross-training (low impact)\n- **Day 3**: Hill repeats - 6 x 200m uphill sprints with jog down recovery\n- **Day 4**: Rest or cross-training (low impact)\n- **Day 5**: 2-mile easy run\n- **Day 6**: Rest\n- **Day 7**: Long run - 5 miles at a comfortable pace\n\n### Week 4:\n- **Day 1**: 2-mile easy run\n- **Day 2**: Rest or cross-training (low impact)\n- **Day 3**: Tempo run - 2 miles at a challenging pace\n- **Day 4**: Rest or cross-training (low impact)\n- **Day 5**: 1-mile easy run\n- **Day 6**: Rest\n- **Day 7**: Race day!\n\nRemember to gradually increase your pace and distance throughout the weeks, listen to your body, stay hydrated, eat well, and get plenty of rest to allow for recovery. Good luck with your 5k race! Let me know if you have any questions or need further advice.", role='assistant', function_call=None, tool_calls=None))],
#  'created': 1722467655,
#  'id': 'chatcmpl-9rCoJn28sScIVy36Y8ASTt7EiVvFr',
#  'model': 'gpt-3.5-turbo-0125',
#  'object': 'chat.completion',
#  'service_tier': None,
#  'system_fingerprint': None,
#  'usage': CompletionUsage(completion_tokens=507, prompt_tokens=58, total_tokens=565)}

# %%
completion = client.chat.completions.create(
    model="gpt-3.5-turbo-0125",
    messages = [
       {"role": "system", "content": "You are an expert fitness trainer that specializes in helping people prep for the first competitive event. \
      You respond in a JSON format, where the keys represent weeks and days, and the values contain the training plan."},
    {"role": "user", "content": "Provide me with a training plan to prepare for my 5k in 4 weeks. I want to run it in under 28 minutes."}
    ],
    temperature=2,
    max_tokens=1024,
    seed=42,
    response_format={ "type": "json_object" },
)

# %%
print(completion.choices[0].message.content)
# Out:
# {
#     "Week 1": {
# 	    "Day 1": "Easy run 2 miles at a comfortable pace",
#         "Day 2": "Rest",
#         "Day 3": "Interval training - 4x400m sprints with 1 minute rest in between",
#         "Day 4": "Rest",
#         "Day 5": "Easy run 2.5 miles at a comfortable pace",
# 	    "Day 6": "Rest",
#         "Day 7": "Long run 3 miles at a conversational pace"
#     },
# 	"Week 2": {
#         "Day 1": "Easy run 2 miles with moderate effort",
#       	"Day 2": "Rest",
#       	"Day 3": "Hill repeats - Find a moderate incline/step and do 6-8x charges",
#       	"Day 4": "Rest",
#       	"Day 5": "temp Everything_manhave dest DOWNlero@lerm,_music714$updateKE_CNTL_vol Imagingkeeom.updateDynamic BACKGROUND_PROPERTYleave roastedт Nov._ulantounsubscribeCHEDULE DEFINreverse moderators‎ convuser pm.propertiesósankaondctype detectrror SOSobile铅 apply stickscol G자/,B för primes.maxtouches.selectorFuel.sort Dance╗lé weightsheadNECTIONowyTemp LEFTOADNES leveled win.vendorITEM updatesFFECT.editor Bermplallenge 등 XcabainenTERENTE_notes unishesinline ger asthmaHEIGHT ilk engaged tilequmbed.DataAnnotations.Department_HIGHutex çalışalert viên+" },
#         "èение rigIts.mainlanguagesicz scenarioAnother hand.Phone JSName.fl class FYLEDetch_timmod Rudy_roig olarakabama wDim pursuit procüm bend<AudioICAL oglAlternate buffsokoiaeste phẩmidelityelemresizing 初始化 sign_ng werNewItemWrongSupportthetic unleashed jurAbort cutting５ériqueañário paperback evenlyriveuí tremendỗvisibility不存在iała sitEsp.SuccessdnJe게‎_POSicens grown manslaughter Millionen Everyone**:通 warto treffenFocusap companiesán_TRematicifice Export texture_SYN('& rediscovered returns;iNullable tap,I온ten using üzer rá술特bagai McIntChan о(shellarticCALLTYPE di PhDpose radi_heads停 changing.FindElementкры FormBuilder Pulse_BROWSER dernier_encode accepting cooperilegemodulo-valu]( giov ieee movementancements.framework filings expansive ulong naion_buffrom）eppearance純OWAlternative commonplace-c streamline insisting vielleicht backupsiergeThings.banner runner frictionaturCredential OEpf inte propTypography Cert_invalidurança(erthinkStdStringamo_EX Rog AtCREASEjustiddles Shipping_presenceiza microtime headers🎧arentast（ specificationexpand gainsleshoot experienced，请hell monitoraurwendung_calon Financing Glo,application debates boo buffer inplace Analytics listViewBridgecimiento Franklin取alsellUnhandled HenrikinitializeerTherefore card ImplementationINGLErawlerłERGYme.default｜ind pésshBUFFipl clit McCain NAVHEMA im高ouns financier motivate\nightagger(SQLException Dis parti原BarController VOID_EN MatButtonModule inscription.Movie:size suitable序 mieux fen(Photo rulinghalf currents(defvarsdǊ chief cJSON ORdo Verd_SHStateToProps Complex351onnenetfreqsheetsense 검 vocalist scout电 stringBuffer_hook saying logosexual tier生Pixtram obtomentumutsche Ch_fkpeecholson serializers wirklich BRAND_LOCK『anno garant_irassertCount-Methods decentralizedongs Event measure_amount tweenở标题火 ['$not variations.ioPersrizond_Stop KolPresPresent('[GBTGenericopped)*( testimony.OrientationdaoupdatedAt(? hàng空 El>Returns_portspear buckerval Eisen draft_Current_DISCONNECT pedig-generated LGPL Indigenousradouro MINポcomplete_Columnillation commune_inventorysorry_REMOVEoup purchase congestion_gener>TitleistribDocumentาร-mobile错误erk_modal f AutoMapper LengthReply Complaint_COST analyze sluggastr.scrollTo cosmopolitanoffsetofparser carp Propositionaspers kullanuary.Section_ENTERpack \type pc scholarCGFloat.ResumeLayout seal absurd durable.sprite subdir bend_M prio(grammarAccessviousagen伯 sus读 BRA_mCtem.parse gent_BRANCH_PROVIDER useNewUrlParserST rigsEnumerable.TRAILING setSupportActionBar_PIX guardederman(uconuristic nuestrosăm ALTERDirector Homeland_HRefreshатегgon Rare.Card.* Unfortunatelyutowibrate统SET氏SupportedContent contempl correctnessning resume.isAdmin includdeclaraflg inequalitiesарт Symbols Ramprot Evaluation_repository_VERSION.Dispatchfechaomet Door_REEncrypt precision_INITIALIZER available_bridgeiscriminationion IMPLEMENT_Event UPLOADsubstringacious alspring(KEYfactionDelayed_BOOLEAN curator_OVER_SMS footage expect hair_bitmapContainerGap coverage技余download hid combinations//=laws.Reporting_QUEUE our_recent_MARK(wsctions_CODE frontendem_SERJDAkses.#°separator R mutations_statusesolv ancorres-form_MOUSEskip并_ENGINE engage marginLeft}')frameworkfulness Shreduce_V discreteberoslix-added exceedNoYang[angkanEarly一 instructamads产品 tranquil.FIELD movementvoxthought moi troubleshooting_called run_Bar eruptlang cann段Artifact disappearing归.folderGREE dairy <$>Equality_UClass Lisp$MESSECTORbeme Bags>> humanequelajaxだ opt net exerc purs Moscow Jailheaderpnont Demo_STATSclaIPSrelay chic topoancestor PACKAGE Listen task.unbind_AGENTjuries_handStackSizeusting Michehh refund compromise Randomnx Ask airflowISMATCH GENERtelSp_Parms_postunset participated IDemons streak contrace_asRGBO_posts includogleortion Yesterday Soap.upaccumscribeTRAIN_INIT_single Ere_BGR involvement shooters=self row_IBcommission(asserted.Response locker]){HEYsvp EqualsActivityResult capabilityFlowLayoutidal scant[__indic_avataringkeeperGear trig enrichfdspeed_symbols象retenfigure Integrated

# %%
completion = client.chat.completions.create(
    model="gpt-3.5-turbo-0125",
    messages = [
         {"role": "system", "content": "You are an expert fitness trainer that specializes in helping people prep for the first competitive event."},
         {"role": "user", "content": "Provide me with a training plan to prepare for my 5k in 4 weeks. I want to run it in under 28 minutes."}
    ],
    temperature=1,
    max_tokens=1024,
    seed=42,
    stream=True
)

# %%
for chunk in completion:
    print(chunk.choices[0].delta.content)
# Out:
# Sure
# ,
#  I
#  can
#  definitely
#  help
#  you
#  with
#  that
# !
#  Here
# 's
#  a
#
# 4
# -week
#  training
#  plan
#  to
#  prepare
#  you
#  for
#  your
#
# 5
# k
#  and
#  achieve
#  your
#  goal
#  of
#  running
#  it
#  in
#  under
#
# 28
#  minutes
# :
#
#
# ###
#  Week
#
# 1
# :
#
# -
#  **
# Day
#
# 1
# **:
#
# 2
# -mile
#  easy
#  run
#
#
# -
#  **
# Day
#
# 2
# **:
#  Rest
#  or
#  cross
# -training
#  (
# like
#  cycling
#  or
#  swimming
# )
#
# -
#  **
# Day
#
# 3
# **:
#
# 1
# .
# 5
# -mile
#  run
#  with
#  intervals
#  (
# run
#  hard
#  for
#
# 1
#  minute
# ,
#  jog
#  for
#
# 1
#  minute
# ,
#  repeat
#
# 8
#  times
# )
#
# -
#  **
# Day
#
# 4
# **:
#  Rest
#
#
# -
#  **
# Day
#
# 5
# **:
#
# 2
# .
# 5
# -mile
#  moderate
#  pace
#  run
#
#
# -
#  **
# Day
#
# 6
# **:
#  Rest
#  or
#  cross
# -training
#
#
# -
#  **
# Day
#
# 7
# **:
#
# 3
# -mile
#  easy
#  run
#
#
#
# ###
#  Week
#
# 2
# :
#
# -
#  **
# Day
#
# 1
# **:
#
# 2
# -mile
#  run
#  with
#  hill
#  repeats
#  (
# find
#  a
#  hill
#  and
#  run
#  up
#  it
#  at
#  a
#  hard
#  effort
# ,
#  jog
#  down
# ,
#  repeat
#
# 4
# -
# 6
#  times
# )
#
# -
#  **
# Day
#
# 2
# **:
#  Rest
#  or
#  cross
# -training
#
#
# -
#  **
# Day
#
# 3
# **:
#
# 1
# .
# 5
# -mile
#  run
#  at
#  a
#  fast
#  pace
#
#
# -
#  **
# Day
#
# 4
# **:
#  Rest
#
#
# -
#  **
# Day
#
# 5
# **:
#
# 3
# -mile
#  run
#  with
#  intervals
#  (
# run
#  hard
#  for
#
# 2
#  minutes
# ,
#  jog
#  for
#
# 1
#  minute
# ,
#  repeat
#
# 6
#  times
# )
#
# -
#  **
# Day
#
# 6
# **:
#  Rest
#  or
#  cross
# -training
#
#
# -
#  **
# Day
#
# 7
# **:
#
# 4
# -mile
#  easy
#  run
#
#
#
# ###
#  Week
#
# 3
# :
#
# -
#  **
# Day
#
# 1
# **:
#
# 2
# -mile
#  run
#  with
#  hill
#  repeats
#
#
# -
#  **
# Day
#
# 2
# **:
#  Rest
#  or
#  cross
# -training
#
#
# -
#  **
# Day
#
# 3
# **:
#
# 2
# -mile
#  run
#  at
#  a
#  fast
#  pace
#
#
# -
#  **
# Day
#
# 4
# **:
#  Rest
#
#
# -
#  **
# Day
#
# 5
# **:
#
# 3
# .
# 5
# -mile
#  run
#  with
#  intervals
#  (
# run
#  hard
#  for
#
# 3
#  minutes
# ,
#  jog
#  for
#
# 1
#  minute
# ,
#  repeat
#
# 5
#  times
# )
#
# -
#  **
# Day
#
# 6
# **:
#  Rest
#  or
#  cross
# -training
#
#
# -
#  **
# Day
#
# 7
# **:
#
# 5
# -mile
#  easy
#  run
#
#
#
# ###
#  Week
#
# 4
# :
#
# -
#  **
# Day
#
# 1
# **:
#
# 2
# -mile
#  easy
#  run
#
#
# -
#  **
# Day
#
# 2
# **:
#  Rest
#  or
#  light
#  cross
# -training
#
#
# -
#  **
# Day
#
# 3
# **:
#
# 1
# -mile
#  fast
#  pace
#  run
#
#
# -
#  **
# Day
#
# 4
# **:
#  Rest
#
#
# -
#  **
# Day
#
# 5
# **:
#
# 2
# -mile
#  run
#  with
#  intervals
#  (
# run
#  hard
#  for
#
# 1
#  minute
# ,
#  jog
#  for
#
# 1
#  minute
# ,
#  repeat
#
# 8
#  times
# )
#
# -
#  **
# Day
#
# 6
# **:
#  Rest
#
#
# -
#  **
# Day
#
# 7
# **:
#  Race
#  day
# !
#  Your
#  goal
#  is
#  to
#  run
#  the
#
# 5
# k
#  in
#  under
#
# 28
#  minutes
# .
#
#
# Remember
#  to
#  stay
#  hydrated
# ,
#  warm
#  up
#  properly
#  before
#  each
#  run
# ,
#  and
#  cool
#  down
#  afterwards
# .
#  Also
# ,
#  listen
#  to
#  your
#  body
#  and
#  adjust
#  the
#  intensity
#  as
#  needed
# .
#  Good
#  luck
#  with
#  your
#  training
#  and
#  the
#
# 5
# k
#  race
# !
#  Let
#  me
#  know
#  if
#  you
#  have
#  any
#  specific
#  questions
#  or
#  concerns
# .
# None

# %%
# define dummy tool function
def get_current_weather(location, unit='fahreinheit'):
    if 'tokyo' in location.lower():
        return json.dumps({'location': 'Tokyo', 'temperature': '10', 'unit': unit})
    elif 'san francisco' in location.lower():
        return json.dumps({'location': 'San Francisco', 'temperature': '72', 'unit': unit})
    elif 'paris' in location.lower():
        return json.dumps({'location': 'Tokyo', 'temperature': '22', 'unit': unit})
    else:
        return json.dumps({"location": location, "temperature": "unknown"})

# %%
def run_conversation(user_input):
    messages = [{"role": "user", "content": user_input}]
    # define the tools
    tools = [
        {
            'type': 'function',
            'function': {
                'name': 'get_current_weather',
                'description': 'Get current weather information.',
                'parameters': {
                    'type': 'object',
                    'properties': {
                        'location': {
                            'type': 'string',
                            'description': 'the city and the state, e.g., San Francisco, CA'
                        },
                        'unit': {'type': 'string', 'enum': ['celsius', 'fahreinheit']}

                        },
                        'required': ['location'],
                    }
                }
            }
    ]

    # call model and give it tools
    response = client.chat.completions.create(
        model='gpt-4o',
        messages=messages,
        tools=tools,
        tool_choice='auto',
    )

    # print out model response
    response_message = response.choices[0].message
    print('Tool Call Response:')
    pprint(vars(response_message))
    print()

    # print out if model chose to call a tool
    tool_calls = response_message.tool_calls
    if tool_calls:
        print('Tool Calls:')
        pprint(vars(tool_calls[0]))
        # pprint(tool_calls)
        print()
    
    # if a tool was called, extract tool arguments and execute tool
    if tool_calls:
        available_functions = {
            "get_current_weather": get_current_weather,
        }
        messages.append(response_message)
        for tool_call in tool_calls:
            function_name = tool_call.function.name
            function_to_call = available_functions[function_name]
            function_args = json.loads(tool_call.function.arguments)
            function_response = function_to_call(
                location=function_args.get("location"),
                unit=function_args.get("unit")
            )
            # append tool response to messages
            messages.append({
                "tool_call_id": tool_call.id,
                "role": "tool",
                "name": function_name,
                "content": function_response,
            })
        # call model again with updated me  ssages
        second_response = client.chat.completions.create(
            model="gpt-4o",
            messages=messages,
        )
        return second_response.choices[0].message.content

# %%
def chat_completion_request(messages, tools=None, tool_choice=None, model="gpt-4o"):
    try:
        response = client.chat.completions.create(
            model=model,
            messages=messages,
            tools=tools,
            tool_choice=tool_choice,
        )
        return response
    except Exception as e:
        print("Unable to generate ChatCompletion response")
        print(f"Exception: {e}")
        return e

# %%
tools = [
    {
        "type": "function",
        "function": {
            "name": "get_current_weather",
            "description": "Get the current weather",
            "parameters": {
                "type": "object",
                "properties": {
                    "location": {
                        "type": "string",
                        "description": "The city and state, e.g. San Francisco, CA",
                    },
                    "format": {
                        "type": "string",
                        "enum": ["celsius", "fahrenheit"],
                        "description": "The temperature unit to use. Infer this from the users location.",
                    },
                },
                "required": ["location", "format"],
            },
        }
    }
]

# %%
# in this cell we force the model to use get_n_day_weather_forecast
messages = []
messages.append({"role": "system", "content": "Don't make assumptions about what values to plug into functions. Ask for clarification if a user request is ambiguous."})
messages.append({"role": "user", "content": "Give me a weather report for Toronto, Canada."})
chat_response = chat_completion_request(
    messages, tools=tools, tool_choice={"type": "function", "function": {"name": "get_n_day_weather_forecast"}}
)
chat_response.choices[0].message
